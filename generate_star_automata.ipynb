# %%
def get_star_transitions(first):
    train_core = []
    test_core = []
    # first 4 nodes (1,2,3,4) in the automaton are connected to the center node

    for i in range(1,5):
        for j in range(i,3+i):
            # start, center, end
            # if i = 2 and first = 0, then we have tuples:
            # (2,5,8),(2,5,9),(2,5,6)
            train_core.append((first+i,first+5,first+6+j%4))
        # for test we would have (2,5,7)
        test_core.append((first+i,first+5,first+i+5))
    return train_core,test_core

train_core = {}
test_core = {}
# create 3 star automata
for i in range(0,3):
    train,test = get_star_transitions(i*9)
    train_core[i+1]=train
    test_core[i+1]= test

automaton2states = {}
# for each automaton, we want to create two states
for i in range(0,9*3):
    automaton2states[i+1] = (i*2+1,i*2+2)
automaton2states
# Out:
# {1: (1, 2),
#  2: (3, 4),
#  3: (5, 6),
#  4: (7, 8),
#  5: (9, 10),
#  6: (11, 12),
#  7: (13, 14),
#  8: (15, 16),
#  9: (17, 18),
#  10: (19, 20),
#  11: (21, 22),
#  12: (23, 24),
#  13: (25, 26),
#  14: (27, 28),
#  15: (29, 30),
#  16: (31, 32),
#  17: (33, 34),
#  18: (35, 36),
#  19: (37, 38),
#  20: (39, 40),
#  21: (41, 42),
#  22: (43, 44),
#  23: (45, 46),
#  24: (47, 48),
#  25: (49, 50),
#  26: (51, 52),
#  27: (53, 54)}

# %%
automaton2states[22]
# Out:
# (43, 44)

# %%
from itertools import combinations
import random
num_stars = 3
train_data = []
test_data = []
distractors = {}
for i in range(num_stars):
    choices = [i%27+1 for i in range((i+1)*9,(i+3)*9)]
    # generate all possible non-repeating triples from choices
    combinations_of_three = list(combinations(choices, 3))
    distractors[i+1]=combinations_of_three
train_dicts = []
for k,tcs in train_core.items():
    for tc in tcs:
        for dist in distractors[k]:
            train_dicts.append({'core':tc,'distractor':dist})

test_dicts = []
for k,tcs in test_core.items():
    for tc in tcs:
        rand_dists = random.sample(distractors[k], 5)
        for dist in rand_dists:
            test_dicts.append({'core':tc,'distractor':dist})

# %%
test_dicts
# Out:
# [{'core': (1, 5, 6), 'distractor': (15, 18, 19)},
#  {'core': (1, 5, 6), 'distractor': (14, 19, 20)},
#  {'core': (1, 5, 6), 'distractor': (15, 24, 26)},
#  {'core': (1, 5, 6), 'distractor': (15, 16, 23)},
#  {'core': (1, 5, 6), 'distractor': (21, 22, 23)},
#  {'core': (2, 5, 7), 'distractor': (15, 19, 25)},
#  {'core': (2, 5, 7), 'distractor': (10, 17, 18)},
#  {'core': (2, 5, 7), 'distractor': (10, 14, 21)},
#  {'core': (2, 5, 7), 'distractor': (10, 22, 27)},
#  {'core': (2, 5, 7), 'distractor': (13, 19, 23)},
#  {'core': (3, 5, 8), 'distractor': (12, 15, 16)},
#  {'core': (3, 5, 8), 'distractor': (20, 24, 26)},
#  {'core': (3, 5, 8), 'distractor': (11, 12, 14)},
#  {'core': (3, 5, 8), 'distractor': (15, 24, 27)},
#  {'core': (3, 5, 8), 'distractor': (11, 15, 24)},
#  {'core': (4, 5, 9), 'distractor': (17, 23, 25)},
#  {'core': (4, 5, 9), 'distractor': (21, 22, 26)},
#  {'core': (4, 5, 9), 'distractor': (15, 16, 17)},
#  {'core': (4, 5, 9), 'distractor': (10, 20, 26)},
#  {'core': (4, 5, 9), 'distractor': (14, 16, 27)},
#  {'core': (10, 14, 15), 'distractor': (22, 7, 9)},
#  {'core': (10, 14, 15), 'distractor': (25, 8, 9)},
#  {'core': (10, 14, 15), 'distractor': (23, 26, 7)},
#  {'core': (10, 14, 15), 'distractor': (24, 6, 7)},
#  {'core': (10, 14, 15), 'distractor': (26, 8, 9)},
#  {'core': (11, 14, 16), 'distractor': (19, 6, 9)},
#  {'core': (11, 14, 16), 'distractor': (25, 5, 7)},
#  {'core': (11, 14, 16), 'distractor': (23, 25, 3)},
#  {'core': (11, 14, 16), 'distractor': (23, 27, 8)},
#  {'core': (11, 14, 16), 'distractor': (21, 1, 9)},
#  {'core': (12, 14, 17), 'distractor': (24, 6, 9)},
#  {'core': (12, 14, 17), 'distractor': (19, 26, 9)},
#  {'core': (12, 14, 17), 'distractor': (21, 1, 8)},
#  {'core': (12, 14, 17), 'distractor': (21, 24, 1)},
#  {'core': (12, 14, 17), 'distractor': (20, 26, 2)},
#  {'core': (13, 14, 18), 'distractor': (26, 2, 4)},
#  {'core': (13, 14, 18), 'distractor': (22, 25, 5)},
#  {'core': (13, 14, 18), 'distractor': (21, 27, 4)},
#  {'core': (13, 14, 18), 'distractor': (23, 6, 7)},
#  {'core': (13, 14, 18), 'distractor': (24, 3, 9)},
#  {'core': (19, 23, 24), 'distractor': (6, 7, 16)},
#  {'core': (19, 23, 24), 'distractor': (7, 15, 17)},
#  {'core': (19, 23, 24), 'distractor': (4, 5, 14)},
#  {'core': (19, 23, 24), 'distractor': (4, 5, 6)},
#  {'core': (19, 23, 24), 'distractor': (4, 9, 11)},
#  {'core': (20, 23, 25), 'distractor': (7, 10, 11)},
#  {'core': (20, 23, 25), 'distractor': (4, 14, 16)},
#  {'core': (20, 23, 25), 'distractor': (5, 12, 15)},
#  {'core': (20, 23, 25), 'distractor': (1, 4, 13)},
#  {'core': (20, 23, 25), 'distractor': (9, 13, 18)},
#  {'core': (21, 23, 26), 'distractor': (11, 14, 18)},
#  {'core': (21, 23, 26), 'distractor': (2, 6, 8)},
#  {'core': (21, 23, 26), 'distractor': (8, 9, 13)},
#  {'core': (21, 23, 26), 'distractor': (3, 4, 6)},
#  {'core': (21, 23, 26), 'distractor': (7, 8, 10)},
#  {'core': (22, 23, 27), 'distractor': (10, 11, 14)},
#  {'core': (22, 23, 27), 'distractor': (9, 11, 13)},
#  {'core': (22, 23, 27), 'distractor': (7, 15, 17)},
#  {'core': (22, 23, 27), 'distractor': (3, 14, 16)},
#  {'core': (22, 23, 27), 'distractor': (5, 7, 18)}]

# %%
# a) one set of transitions where 3 automata are needed
# b) one set of transitions where only 2 automata are needed
# c) one set of transition where only 1 automaton is needed

# a) input format: [22:0, 23:0, 27:0, 1:0, 5:0, 11:0, 27:1]
# b) input format: [22:1, 23:0, 27:0, 1:0, 5:0, 11:0, 27:1]
# c) input format: [22:1, 23:1, 27:0, 1:0, 5:0, 11:0, 27:1]

# next create training samples by permuting the 6 first elements of the input and storing the position of the relevant automaton as output

# %%
from collections import defaultdict
import random
# TODO: přidat d), kde první dva stavy - druhý je dobře nastavený ale první je špatně
def create_transition_sets(test_dicts, automaton2states):
    result = defaultdict(list)

    for example in test_dicts:
        core = example['core'] # (22, 23, 27)
        distractor = example['distractor'] # (1, 4, 10)
        
        # a)
        input_dict_a = {}
        for node in core:
            input_dict_a[node] = automaton2states[node][0] # na 22 dám 43 (0), na 23 dám 45 (0), na 27 dám 53 (0) 
        for node in distractor:
            input_dict_a[node] = random.choice(automaton2states[node]) # na 1, 4, 10 dám náhodným výběrem stav, tzn. na 4 dám buď 7 nebo 8 (0 nebo 1)
        
        output_dict = {core[2]: automaton2states[core[2]][1]} # 3 automat v pořadí je finální, na něj dám stav 54 (1).
        result['a'].append({'in': input_dict_a, 'out': output_dict})
        
        # b)
        input_dict_b = {}
        for node in core:
            input_dict_b[node] = automaton2states[node][0] # stejné jako předtím
        input_dict_b[core[0]] = automaton2states[core[0]][1] # tady ale na v pořadí první automat 22 dám stav 44 (1)
        for node in distractor:
            input_dict_b[node] = input_dict_a[node]  # distractory mají stejné stavy pro a, b, c
        result['b'].append({'in': input_dict_b, 'out': output_dict})
        
        # c)
        input_dict_c = {}
        for node in core:
            input_dict_c[node] = automaton2states[node][0]
        input_dict_c[core[0]] = automaton2states[core[0]][1] # tady dávám na 22 stav 44 (1)
        input_dict_c[core[1]] = automaton2states[core[1]][1] # tady dávám na 23 stav 46 (1)
        for node in distractor:
            input_dict_c[node] = input_dict_a[node]  # distractory mají stejné stavy pro a, b, c
        result['c'].append({'in': input_dict_c, 'out': output_dict})

    return result

# %%
test_transition_sets = create_transition_sets(test_dicts, automaton2states)
train_transition_sets = create_transition_sets(train_dicts, automaton2states)
#sample:
for i, case in enumerate(['a', 'b', 'c']):
    print(f"{case}) {i+1}:")
    print(test_transition_sets[case][59])
    print()
# Out:
# a) 1:
# {'in': {22: 43, 23: 45, 27: 53, 5: 10, 7: 13, 18: 36}, 'out': {27: 54}}
#
# b) 2:
# {'in': {22: 44, 23: 45, 27: 53, 5: 10, 7: 13, 18: 36}, 'out': {27: 54}}
#
# c) 3:
# {'in': {22: 44, 23: 46, 27: 53, 5: 10, 7: 13, 18: 36}, 'out': {27: 54}}

# %%
len(train_transition_sets["a"]) * 3
# Out:
# 88128

# %%
# {'in': {22: 43, 23: 45, 27: 53, 4: 8, 12: 24, 16: 31}, 'out': {27: 54}}

# dict {input: [43, 53, 45, 8, 24, 31, 54], out: 0}

# {'in': {22: 44, 23: 45, 27: 53, 4: 8, 12: 24, 16: 31}, 'out': {27: 54}}

# dict {input: [43, 53, 45, 8, 24, 31, 54], out: 2}

# {'in': {22: 44, 23: 46, 27: 53, 4: 8, 12: 24, 16: 31}, 'out': {27: 54}}

# dict {[input: 43, 45, 8, 24, 31, 54], out: 1}

# 20 * 88128

# %%
train_transition_sets["c"][0]
# Out:
# {'in': {1: 2, 5: 10, 7: 13, 10: 20, 11: 21, 12: 23}, 'out': {7: 14}}

# %%
# vytvořit vektory
# 7 položek - poslední položka je cílové id_stavu 
# 6 předchozích jsou id stavů ale ty permutujeme (20 náhodných permutací)
# bude dict, kde 6 čísel bude permutovaných a 7 nechávám jak je - tj. dict {input: [vektor], output: [idx_pozice_automatu]}

# %%
import random
from itertools import permutations

def extract_state(transition_sets, num_permutations=20):
    result = []

    for case, t_set in transition_sets.items():
        for dicts in t_set:
            input_dict = dicts["in"]
            output_dict = dicts["out"]
            
            # prvních 6 stavů vytáhnu
            states = list(input_dict.values())[:6]
            # a vytáhnu výstupní stav
            output_state = list(output_dict.values())[0]
            
            # prozatím pro C, tady se vytáhne podle pozice stav, který je třeba změnit
            if case == 'c':
                target_state = states[2]
            else:
                continue
            # if case == 'b':
            #     target_state = states[1] 
            # if case == 'a':
            #     target_state = states[0] 
            
            # prvních 6 stavů - permutace
            permutations_list = list(permutations(states))
            # výběr 20
            selected_permutations = random.sample(permutations_list, num_permutations)
            # pro každou permutaci
            for perm in selected_permutations:
                # do listu dát tuto permutaci a výstupní stav
                input_list = list(perm) + [output_state]
                # do out hodit index cílového stavu
                orig_idx = input_list.index(target_state)
                out = orig_idx+55
                # dát do dictu
                result.append({'input': input_list, 'out': out, 'orig_idx': orig_idx})

    return result

data_train = extract_state(train_transition_sets)
data_test = extract_state(test_transition_sets)

# %%
data = {"train": data_train, "test": data_test}

# %%
import pickle
with open ("data.pkl", "wb") as f:
    pickle.dump(data, f)

# %%
data
# Out:
# {'train': [{'input': [13, 10, 20, 23, 21, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 20, 23, 21, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [23, 20, 10, 13, 21, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 13, 23, 21, 20, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 13, 10, 20, 21, 23, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [21, 13, 2, 20, 10, 23, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [20, 23, 2, 21, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [21, 2, 23, 20, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [21, 13, 20, 2, 23, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [20, 21, 23, 10, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 20, 23, 2, 21, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 21, 2, 20, 23, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 23, 10, 20, 21, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 13, 20, 21, 23, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [21, 13, 20, 10, 2, 23, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 2, 10, 20, 23, 21, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [21, 10, 13, 2, 23, 20, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [23, 10, 2, 21, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 21, 10, 2, 23, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 21, 20, 13, 2, 23, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [25, 22, 2, 19, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 22, 2, 19, 25, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [25, 2, 19, 22, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [25, 19, 13, 10, 22, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [22, 13, 19, 25, 2, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 19, 22, 25, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 2, 25, 19, 13, 22, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 25, 19, 22, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [22, 13, 19, 25, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [25, 19, 13, 22, 10, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [25, 2, 10, 13, 22, 19, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [25, 10, 22, 13, 19, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [22, 19, 10, 25, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 2, 10, 25, 19, 22, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [22, 2, 13, 19, 10, 25, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 19, 2, 10, 22, 25, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 22, 25, 10, 13, 19, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [19, 2, 22, 10, 25, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 2, 19, 13, 25, 22, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [19, 2, 22, 25, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 20, 28, 2, 22, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [28, 10, 20, 22, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 20, 2, 28, 10, 22, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [20, 13, 28, 22, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 13, 20, 10, 22, 28, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 13, 28, 20, 10, 22, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 20, 10, 22, 2, 28, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 2, 20, 28, 10, 22, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 28, 2, 22, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 20, 13, 28, 22, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 20, 10, 22, 28, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [22, 2, 28, 13, 10, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 20, 22, 28, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [28, 10, 22, 13, 20, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [22, 28, 10, 13, 2, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 2, 20, 22, 10, 28, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [28, 13, 10, 2, 20, 22, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [28, 10, 20, 22, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [22, 20, 13, 28, 2, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [20, 13, 2, 28, 22, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [22, 30, 20, 2, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [20, 13, 30, 22, 2, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 22, 20, 2, 30, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [22, 20, 2, 10, 30, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [22, 20, 13, 30, 10, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [22, 30, 10, 2, 13, 20, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [30, 22, 13, 10, 2, 20, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [22, 10, 20, 2, 30, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 20, 22, 2, 30, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 10, 30, 20, 22, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [30, 22, 20, 10, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [20, 30, 13, 10, 22, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [20, 2, 13, 30, 22, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 22, 2, 10, 30, 20, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 22, 20, 2, 13, 30, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 2, 13, 22, 30, 20, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [30, 10, 20, 13, 2, 22, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 22, 2, 20, 10, 30, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 20, 2, 13, 22, 30, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [20, 10, 2, 13, 22, 30, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [20, 31, 13, 21, 10, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [21, 2, 31, 10, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 21, 13, 31, 20, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [20, 10, 21, 2, 13, 31, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [31, 10, 21, 2, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 2, 31, 21, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 21, 10, 31, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [21, 31, 2, 20, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 31, 20, 21, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 31, 10, 13, 2, 21, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 10, 31, 20, 13, 21, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [21, 10, 31, 13, 2, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 21, 31, 10, 20, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [20, 21, 2, 31, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [20, 10, 21, 2, 31, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 21, 10, 20, 13, 31, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [21, 31, 13, 2, 10, 20, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [20, 31, 13, 2, 10, 21, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [20, 21, 31, 10, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 10, 20, 31, 2, 21, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [21, 2, 10, 33, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 10, 2, 33, 13, 21, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [33, 10, 13, 21, 2, 20, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 2, 20, 33, 21, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 33, 21, 10, 2, 20, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 2, 21, 20, 13, 33, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [20, 13, 10, 21, 2, 33, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [21, 10, 13, 20, 33, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 21, 2, 33, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 10, 2, 13, 33, 21, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [20, 13, 33, 2, 10, 21, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [21, 20, 2, 13, 10, 33, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 33, 21, 20, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 10, 33, 2, 20, 21, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 2, 20, 13, 33, 21, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [20, 33, 2, 10, 13, 21, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 33, 10, 13, 21, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [21, 33, 10, 2, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 13, 21, 2, 33, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 33, 21, 13, 10, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 21, 19, 35, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [21, 10, 35, 13, 2, 19, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [21, 19, 2, 35, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 13, 35, 19, 21, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [35, 10, 13, 19, 2, 21, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [2, 21, 35, 10, 19, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 13, 35, 10, 21, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 35, 13, 21, 19, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [2, 21, 10, 35, 13, 19, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [35, 10, 13, 19, 21, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 10, 21, 2, 19, 35, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [19, 2, 10, 13, 21, 35, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [21, 19, 13, 2, 10, 35, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [19, 35, 10, 2, 21, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 13, 10, 21, 19, 35, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 13, 35, 2, 21, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 19, 13, 10, 21, 35, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 21, 19, 13, 2, 35, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 2, 35, 19, 21, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [35, 21, 10, 19, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 10, 37, 20, 13, 21, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 13, 20, 37, 10, 21, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 20, 37, 10, 21, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [21, 20, 37, 10, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 2, 10, 21, 37, 20, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 2, 21, 37, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 20, 13, 10, 37, 21, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 37, 20, 21, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 2, 37, 20, 21, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 37, 13, 21, 10, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [21, 37, 20, 2, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 20, 21, 13, 10, 37, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 10, 13, 20, 37, 21, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [20, 21, 37, 2, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [21, 37, 20, 2, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 2, 20, 21, 10, 37, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 21, 20, 37, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [21, 20, 10, 2, 13, 37, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 21, 20, 13, 10, 37, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [20, 13, 37, 21, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [22, 10, 19, 13, 40, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [22, 2, 10, 40, 13, 19, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [40, 13, 2, 10, 22, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 19, 22, 40, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 40, 22, 19, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [19, 10, 2, 22, 40, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [40, 13, 10, 19, 2, 22, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [19, 10, 40, 2, 13, 22, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 19, 2, 40, 22, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 13, 10, 19, 40, 22, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 10, 40, 19, 13, 22, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [19, 13, 10, 2, 22, 40, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [40, 2, 13, 19, 10, 22, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [22, 40, 13, 10, 2, 19, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [19, 22, 13, 2, 40, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 10, 22, 19, 2, 40, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 40, 13, 10, 19, 22, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [40, 2, 10, 13, 19, 22, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 10, 13, 22, 19, 40, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 22, 19, 2, 40, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 22, 13, 10, 41, 20, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [20, 10, 13, 22, 2, 41, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [41, 2, 20, 10, 22, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 22, 13, 41, 2, 20, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [20, 41, 10, 22, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 2, 20, 13, 22, 41, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [22, 2, 10, 20, 41, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [41, 20, 2, 13, 22, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 20, 2, 13, 41, 22, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 10, 2, 41, 20, 22, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 10, 41, 22, 13, 20, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [20, 10, 2, 22, 13, 41, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [20, 10, 2, 13, 41, 22, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 13, 41, 22, 20, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [41, 13, 10, 22, 20, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 41, 22, 20, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [41, 10, 20, 2, 22, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 22, 20, 41, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [41, 20, 10, 2, 22, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [41, 13, 22, 20, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [22, 13, 44, 2, 10, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [44, 10, 22, 13, 2, 19, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [19, 22, 10, 13, 2, 44, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 22, 19, 44, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 19, 44, 2, 22, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 19, 2, 22, 13, 44, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 10, 19, 22, 44, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 19, 44, 22, 2, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [22, 13, 10, 44, 19, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 19, 2, 22, 44, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 2, 44, 13, 22, 19, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [22, 44, 19, 13, 10, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 22, 10, 44, 19, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 10, 2, 22, 19, 44, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 44, 19, 22, 10, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [22, 2, 19, 13, 44, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 19, 44, 22, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 2, 44, 10, 22, 19, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 44, 22, 19, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [19, 10, 13, 44, 22, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 10, 20, 2, 21, 46, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [20, 2, 46, 10, 21, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 21, 20, 46, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 21, 2, 20, 46, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [21, 13, 20, 2, 46, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 10, 20, 13, 21, 46, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 13, 10, 46, 20, 21, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [46, 21, 2, 20, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [20, 21, 13, 10, 46, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [20, 13, 2, 10, 46, 21, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 10, 46, 2, 20, 21, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 21, 46, 20, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 20, 13, 21, 46, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [46, 13, 21, 10, 20, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [46, 20, 21, 10, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 46, 20, 10, 13, 21, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 10, 46, 20, 21, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [21, 10, 46, 13, 2, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [20, 13, 10, 21, 2, 46, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [46, 10, 2, 21, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 48, 13, 22, 19, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [48, 13, 2, 19, 22, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [48, 2, 22, 13, 19, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 19, 2, 22, 48, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 10, 19, 22, 2, 48, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [48, 13, 2, 22, 10, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 22, 13, 48, 10, 19, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [48, 13, 19, 2, 10, 22, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 19, 10, 48, 22, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [48, 22, 19, 2, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [48, 2, 19, 22, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 22, 19, 48, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [48, 22, 10, 19, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [19, 13, 10, 2, 22, 48, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 22, 2, 13, 48, 19, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [19, 10, 22, 13, 2, 48, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 2, 19, 22, 48, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 10, 22, 19, 48, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [22, 2, 13, 19, 48, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [22, 10, 48, 2, 19, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [21, 50, 2, 19, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 21, 19, 2, 13, 50, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 19, 10, 50, 21, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [19, 50, 13, 21, 2, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 2, 19, 13, 21, 50, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 50, 13, 19, 21, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [19, 13, 50, 21, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 19, 21, 13, 10, 50, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 19, 13, 21, 50, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [50, 21, 10, 19, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [19, 50, 10, 13, 2, 21, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 21, 50, 19, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 19, 2, 10, 50, 21, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [21, 19, 50, 10, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 19, 21, 2, 50, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 10, 19, 21, 2, 50, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 19, 2, 10, 21, 50, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 50, 19, 21, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 21, 19, 50, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [21, 10, 2, 13, 50, 19, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [19, 13, 51, 10, 21, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [21, 19, 10, 51, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 19, 13, 21, 51, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [2, 13, 19, 21, 10, 51, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 19, 51, 13, 21, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 51, 13, 19, 21, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [21, 13, 10, 2, 51, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 2, 21, 19, 51, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 13, 19, 10, 21, 51, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [19, 21, 10, 13, 51, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 21, 51, 10, 13, 19, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [51, 21, 13, 19, 2, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [19, 10, 51, 13, 21, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [51, 19, 21, 13, 2, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 21, 13, 19, 51, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [19, 13, 51, 10, 2, 21, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [51, 19, 13, 2, 21, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [51, 13, 19, 21, 2, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [19, 10, 21, 51, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [51, 21, 10, 2, 13, 19, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 19, 22, 54, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [22, 2, 10, 54, 13, 19, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [22, 13, 54, 19, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 13, 22, 2, 54, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 19, 10, 22, 54, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [19, 10, 22, 13, 2, 54, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 13, 22, 10, 19, 54, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [54, 13, 2, 22, 19, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 54, 2, 22, 10, 19, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 22, 54, 13, 19, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 22, 13, 54, 10, 19, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 13, 54, 19, 22, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 19, 10, 22, 2, 54, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 54, 22, 19, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 22, 19, 13, 54, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [19, 2, 10, 22, 54, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [54, 19, 2, 10, 13, 22, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 54, 19, 10, 22, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 54, 22, 2, 13, 19, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 22, 19, 10, 13, 54, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 23, 2, 25, 13, 19, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 19, 25, 23, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 23, 10, 2, 25, 19, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 23, 25, 2, 13, 19, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 23, 10, 13, 19, 25, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 19, 25, 10, 2, 23, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [25, 10, 13, 23, 2, 19, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 25, 13, 19, 2, 23, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [23, 10, 13, 19, 2, 25, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [25, 2, 10, 13, 23, 19, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [19, 25, 10, 2, 23, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [23, 13, 2, 19, 10, 25, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 19, 23, 10, 25, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [23, 2, 13, 19, 10, 25, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [19, 23, 2, 10, 13, 25, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 25, 19, 2, 23, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 25, 23, 13, 2, 19, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 25, 23, 19, 2, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [23, 19, 2, 13, 25, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [25, 13, 2, 23, 10, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [19, 2, 23, 13, 27, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [19, 23, 2, 27, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 27, 23, 13, 19, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [27, 2, 10, 13, 19, 23, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [19, 13, 23, 27, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 27, 19, 2, 10, 23, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 10, 19, 23, 27, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 27, 2, 13, 19, 23, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [27, 10, 13, 2, 19, 23, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [19, 13, 27, 23, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [23, 13, 10, 2, 19, 27, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 13, 27, 19, 23, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 23, 19, 27, 2, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [27, 19, 2, 10, 13, 23, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 23, 27, 19, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [27, 2, 13, 23, 10, 19, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 23, 13, 27, 19, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [19, 2, 27, 13, 23, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [23, 10, 19, 13, 2, 27, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 13, 23, 19, 27, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [29, 2, 10, 13, 23, 19, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [19, 10, 23, 2, 13, 29, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 29, 19, 23, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 10, 29, 23, 19, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 19, 13, 2, 29, 23, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 23, 10, 19, 29, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [23, 2, 19, 13, 10, 29, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 2, 23, 29, 19, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 19, 10, 23, 29, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 19, 10, 29, 23, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 19, 13, 23, 29, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 2, 29, 19, 23, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 2, 19, 23, 29, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [19, 10, 23, 29, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 19, 2, 23, 29, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 10, 13, 19, 29, 23, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [23, 13, 10, 29, 2, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 29, 10, 19, 23, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [19, 29, 10, 13, 23, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 10, 23, 29, 19, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 24, 10, 2, 13, 31, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 20, 10, 2, 24, 31, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 10, 20, 31, 2, 24, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 20, 10, 2, 31, 24, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 10, 31, 20, 13, 24, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [20, 24, 10, 31, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 10, 13, 24, 2, 31, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 2, 31, 20, 10, 24, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [31, 10, 20, 24, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 10, 31, 24, 2, 20, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [20, 10, 31, 13, 24, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 13, 24, 31, 20, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 20, 31, 24, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 20, 31, 10, 24, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [31, 13, 20, 10, 24, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [31, 20, 2, 24, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [24, 13, 31, 2, 10, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [24, 13, 31, 20, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 2, 20, 24, 31, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 24, 31, 2, 20, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 13, 24, 34, 2, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 20, 13, 24, 34, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [2, 20, 34, 13, 10, 24, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 2, 10, 20, 24, 34, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 24, 13, 20, 10, 34, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 2, 34, 13, 24, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [20, 13, 34, 2, 24, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 20, 13, 10, 34, 24, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [34, 13, 10, 24, 20, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 10, 2, 24, 20, 34, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 24, 13, 34, 20, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [20, 24, 34, 10, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 10, 20, 34, 24, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 34, 13, 10, 20, 24, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 2, 24, 34, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 10, 20, 2, 34, 24, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [20, 34, 24, 13, 2, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 34, 20, 2, 10, 24, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 24, 2, 20, 34, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 13, 10, 20, 34, 24, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 20, 24, 2, 10, 36, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 2, 10, 36, 24, 20, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [24, 13, 36, 10, 2, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [36, 2, 13, 24, 10, 20, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 20, 24, 2, 36, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 20, 13, 24, 36, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 2, 36, 20, 13, 24, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [36, 20, 13, 24, 10, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [24, 36, 2, 10, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 10, 24, 20, 2, 36, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [36, 13, 24, 10, 20, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 20, 24, 2, 13, 36, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 24, 10, 2, 20, 36, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 20, 24, 36, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 20, 24, 2, 36, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [36, 2, 13, 24, 20, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [24, 13, 20, 10, 36, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [24, 36, 2, 10, 13, 20, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [24, 2, 36, 13, 10, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [24, 2, 36, 20, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 19, 2, 10, 24, 37, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 10, 24, 37, 19, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 13, 24, 37, 2, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [19, 37, 24, 13, 10, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 10, 19, 37, 13, 24, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 24, 10, 37, 2, 19, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 24, 13, 19, 10, 37, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [37, 24, 2, 13, 19, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [24, 2, 19, 13, 37, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [24, 19, 10, 13, 37, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 24, 37, 19, 2, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 10, 19, 37, 24, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 13, 2, 24, 37, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 24, 37, 10, 13, 19, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [24, 19, 10, 37, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [24, 13, 19, 10, 2, 37, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [19, 24, 2, 13, 37, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 37, 10, 24, 19, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 10, 19, 2, 37, 24, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [37, 10, 24, 19, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [19, 2, 24, 13, 10, 39, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 19, 24, 10, 2, 39, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [39, 19, 2, 13, 10, 24, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [24, 19, 13, 10, 2, 39, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [19, 24, 39, 13, 2, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [19, 2, 13, 10, 39, 24, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 39, 24, 10, 2, 19, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 39, 19, 10, 24, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 13, 24, 19, 10, 39, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 39, 2, 13, 19, 24, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [24, 19, 2, 10, 39, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [19, 39, 2, 13, 10, 24, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 13, 10, 39, 19, 24, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 39, 19, 24, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 10, 24, 39, 2, 19, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 24, 39, 19, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 19, 39, 24, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [24, 10, 39, 19, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 24, 2, 13, 19, 39, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 24, 19, 39, 2, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 42, 20, 23, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 20, 23, 10, 13, 42, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 20, 2, 13, 23, 42, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [20, 42, 2, 23, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 13, 2, 42, 23, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [42, 13, 23, 2, 20, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 42, 20, 2, 13, 23, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 20, 42, 23, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [23, 20, 2, 13, 10, 42, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 42, 13, 10, 23, 20, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [2, 23, 20, 42, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [42, 2, 13, 10, 20, 23, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [20, 10, 42, 2, 23, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [42, 13, 10, 23, 2, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 42, 10, 23, 20, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 20, 42, 10, 2, 23, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 23, 10, 20, 42, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 20, 10, 42, 13, 23, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [42, 10, 2, 23, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 20, 23, 42, 2, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [23, 20, 13, 10, 43, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 2, 20, 43, 23, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [23, 10, 13, 20, 43, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [2, 43, 23, 13, 20, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [43, 10, 20, 23, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 43, 10, 20, 13, 23, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 20, 13, 2, 23, 43, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [43, 20, 10, 13, 23, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [20, 43, 10, 13, 23, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 43, 20, 23, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 43, 13, 23, 20, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [43, 2, 13, 20, 10, 23, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [43, 2, 23, 13, 20, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [43, 13, 20, 2, 23, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [23, 13, 10, 2, 43, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [20, 43, 13, 10, 23, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [23, 43, 10, 20, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 23, 43, 20, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 10, 23, 43, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [23, 10, 13, 20, 2, 43, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 24, 10, 2, 46, 19, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [19, 10, 24, 46, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [24, 19, 10, 13, 46, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [46, 10, 2, 19, 24, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [24, 10, 19, 46, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 46, 13, 24, 10, 19, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 10, 24, 19, 46, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [24, 46, 13, 2, 10, 19, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 24, 46, 2, 19, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 10, 19, 46, 2, 24, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 10, 13, 46, 19, 24, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [24, 19, 46, 13, 10, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [24, 10, 19, 13, 2, 46, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 24, 19, 10, 13, 46, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [46, 13, 19, 10, 2, 24, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [19, 13, 46, 24, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [19, 24, 2, 10, 46, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [24, 46, 19, 13, 2, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [46, 13, 10, 24, 2, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [19, 13, 46, 2, 10, 24, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [23, 47, 20, 10, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [47, 20, 23, 13, 10, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [23, 13, 47, 2, 10, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [20, 47, 13, 10, 23, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 2, 23, 20, 47, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 10, 2, 23, 20, 47, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 47, 20, 10, 23, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 2, 10, 20, 47, 23, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 20, 10, 13, 47, 23, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [23, 13, 10, 2, 20, 47, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [20, 10, 13, 23, 47, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [2, 23, 10, 47, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [47, 13, 20, 23, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 23, 2, 13, 47, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [47, 2, 10, 13, 20, 23, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 20, 23, 2, 47, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 10, 20, 23, 13, 47, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 23, 2, 20, 10, 47, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 10, 47, 20, 13, 23, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 47, 20, 23, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [19, 49, 2, 13, 23, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 49, 23, 10, 19, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 19, 13, 23, 10, 49, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 23, 19, 2, 10, 49, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [19, 2, 10, 13, 49, 23, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 49, 10, 23, 19, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [49, 23, 2, 10, 13, 19, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 23, 49, 19, 10, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [19, 13, 23, 2, 49, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [23, 19, 10, 13, 2, 49, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 19, 10, 49, 2, 23, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [49, 10, 2, 23, 19, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [23, 13, 2, 10, 19, 49, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [23, 2, 49, 13, 19, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [23, 19, 2, 10, 13, 49, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [23, 2, 19, 13, 49, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 19, 10, 23, 2, 49, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 13, 19, 49, 23, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [49, 23, 2, 19, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 10, 49, 19, 23, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 13, 23, 51, 2, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [23, 51, 10, 2, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 23, 51, 10, 20, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 51, 2, 23, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 13, 10, 2, 23, 51, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [51, 20, 10, 2, 23, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 23, 10, 51, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 51, 10, 23, 2, 20, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 10, 51, 13, 20, 23, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 51, 23, 10, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 2, 20, 23, 10, 51, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 10, 20, 51, 23, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [23, 20, 2, 13, 10, 51, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [23, 51, 20, 10, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 20, 10, 51, 23, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [51, 23, 20, 10, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 13, 20, 23, 10, 51, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [20, 23, 13, 10, 2, 51, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 2, 20, 51, 23, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 20, 23, 51, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 2, 20, 54, 13, 24, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 10, 2, 20, 24, 54, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [54, 24, 20, 10, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [54, 2, 24, 13, 20, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [20, 10, 2, 54, 13, 24, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [54, 10, 13, 24, 20, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [20, 54, 24, 10, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 10, 20, 24, 2, 54, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [24, 13, 10, 54, 2, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 13, 10, 24, 54, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 10, 24, 54, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 24, 13, 20, 54, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 20, 24, 54, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [20, 24, 2, 13, 54, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 20, 24, 10, 2, 54, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 54, 13, 20, 10, 24, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 24, 2, 54, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 10, 20, 54, 13, 24, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 20, 54, 24, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 10, 2, 20, 54, 24, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [26, 2, 10, 13, 27, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [26, 27, 2, 10, 13, 20, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [27, 20, 10, 26, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [26, 27, 20, 2, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 26, 27, 10, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 26, 27, 2, 20, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 20, 10, 26, 27, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [27, 10, 26, 13, 2, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [27, 13, 26, 2, 10, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 13, 20, 10, 26, 27, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 20, 27, 10, 26, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 10, 26, 13, 27, 2, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 26, 13, 2, 27, 20, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [2, 13, 26, 27, 10, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 27, 20, 26, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 20, 13, 26, 10, 27, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 2, 26, 20, 10, 27, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 13, 27, 20, 26, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 20, 27, 26, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [27, 26, 2, 13, 10, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [26, 20, 10, 13, 2, 29, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 10, 20, 26, 13, 29, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [26, 13, 2, 29, 20, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 20, 26, 29, 2, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 29, 26, 13, 10, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [26, 20, 13, 2, 10, 29, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [26, 10, 13, 29, 20, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [26, 13, 2, 10, 20, 29, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 29, 10, 20, 26, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 20, 2, 10, 29, 26, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 29, 20, 2, 26, 10, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 10, 26, 20, 13, 29, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [26, 29, 10, 13, 2, 20, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [29, 20, 2, 26, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [29, 10, 2, 13, 20, 26, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [20, 10, 13, 2, 26, 29, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [2, 29, 26, 10, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [26, 2, 29, 10, 13, 20, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 10, 20, 13, 26, 29, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 10, 20, 13, 29, 26, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [31, 2, 10, 25, 19, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [10, 19, 13, 2, 31, 25, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [2, 13, 25, 10, 31, 19, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 2, 31, 19, 25, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [19, 13, 25, 31, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [19, 10, 2, 31, 25, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [19, 2, 10, 31, 13, 25, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [25, 31, 2, 19, 13, 10, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [31, 25, 13, 10, 19, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [2, 25, 13, 31, 19, 10, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [25, 19, 10, 2, 13, 31, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [10, 13, 25, 19, 31, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [19, 2, 31, 25, 10, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 13, 19, 25, 31, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 2, 25, 10, 31, 19, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [13, 10, 25, 2, 19, 31, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [25, 19, 10, 31, 13, 2, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [25, 31, 2, 13, 19, 10, 14], 'out': 58, 'orig_idx': 3},
#   {'input': [10, 2, 25, 19, 31, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [19, 31, 10, 25, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 10, 13, 2, 33, 26, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 33, 2, 26, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [2, 20, 26, 10, 13, 33, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [26, 20, 13, 33, 10, 2, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 26, 2, 20, 10, 33, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [26, 13, 20, 33, 2, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 13, 26, 10, 33, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [26, 13, 33, 10, 20, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [33, 10, 2, 26, 13, 20, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [33, 13, 26, 10, 20, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 13, 20, 33, 26, 10, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [33, 10, 2, 26, 20, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 20, 33, 26, 10, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [10, 2, 33, 20, 26, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [33, 13, 26, 10, 2, 20, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [26, 10, 20, 33, 2, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [13, 20, 33, 2, 10, 26, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [26, 13, 33, 20, 10, 2, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [20, 10, 2, 33, 26, 13, 14], 'out': 60, 'orig_idx': 5},
#   {'input': [20, 10, 2, 33, 13, 26, 14], 'out': 59, 'orig_idx': 4},
#   {'input': [2, 19, 13, 26, 10, 35, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 35, 26, 10, 19, 2, 14], 'out': 55, 'orig_idx': 0},
#   {'input': [2, 19, 13, 35, 10, 26, 14], 'out': 57, 'orig_idx': 2},
#   {'input': [10, 13, 2, 19, 26, 35, 14], 'out': 56, 'orig_idx': 1},
#   {'input': [13, 19, 26, 2, 10, 35, 14], 'out': 55, 'orig_idx': 0},
# ...
#   {'input': [46, 35, 12, 14, 28, 26, 36], 'out': 56, 'orig_idx': 1},
#   {'input': [35, 26, 14, 46, 28, 12, 36], 'out': 55, 'orig_idx': 0},
#   {'input': [46, 35, 26, 28, 12, 14, 36], 'out': 56, 'orig_idx': 1},
#   {'input': [35, 12, 46, 14, 26, 28, 36], 'out': 55, 'orig_idx': 0},
#   {'input': [14, 26, 28, 35, 12, 46, 36], 'out': 58, 'orig_idx': 3},
#   {'input': [35, 14, 28, 12, 46, 26, 36], 'out': 55, 'orig_idx': 0},
#   {'input': [46, 14, 26, 12, 28, 35, 36], 'out': 60, 'orig_idx': 5},
#   {'input': [46, 12, 26, 28, 35, 14, 36], 'out': 59, 'orig_idx': 4},
#   {'input': [35, 46, 14, 12, 26, 28, 36], 'out': 55, 'orig_idx': 0},
#   {'input': [14, 26, 12, 28, 46, 35, 36], 'out': 60, 'orig_idx': 5},
#   {'input': [46, 28, 12, 26, 14, 35, 36], 'out': 60, 'orig_idx': 5},
#   {'input': [35, 28, 46, 14, 26, 12, 36], 'out': 55, 'orig_idx': 0},
#   {'input': [35, 26, 46, 12, 28, 14, 36], 'out': 55, 'orig_idx': 0},
#   {'input': [35, 14, 46, 12, 28, 26, 36], 'out': 55, 'orig_idx': 0},
#   {'input': [17, 26, 35, 6, 47, 28, 36], 'out': 57, 'orig_idx': 2},
#   {'input': [35, 28, 17, 26, 6, 47, 36], 'out': 55, 'orig_idx': 0},
#   {'input': [26, 28, 6, 47, 35, 17, 36], 'out': 59, 'orig_idx': 4},
#   {'input': [47, 35, 17, 26, 28, 6, 36], 'out': 56, 'orig_idx': 1},
#   {'input': [26, 17, 35, 47, 6, 28, 36], 'out': 57, 'orig_idx': 2},
#   {'input': [47, 17, 28, 35, 6, 26, 36], 'out': 58, 'orig_idx': 3},
#   {'input': [6, 26, 28, 35, 17, 47, 36], 'out': 58, 'orig_idx': 3},
#   {'input': [47, 35, 26, 28, 17, 6, 36], 'out': 56, 'orig_idx': 1},
#   {'input': [17, 28, 35, 26, 47, 6, 36], 'out': 57, 'orig_idx': 2},
#   {'input': [6, 28, 47, 17, 26, 35, 36], 'out': 60, 'orig_idx': 5},
#   {'input': [28, 26, 17, 47, 6, 35, 36], 'out': 60, 'orig_idx': 5},
#   {'input': [35, 28, 47, 6, 26, 17, 36], 'out': 55, 'orig_idx': 0},
#   {'input': [28, 35, 26, 17, 47, 6, 36], 'out': 56, 'orig_idx': 1},
#   {'input': [17, 47, 28, 26, 35, 6, 36], 'out': 59, 'orig_idx': 4},
#   {'input': [6, 47, 28, 17, 35, 26, 36], 'out': 59, 'orig_idx': 4},
#   {'input': [28, 26, 17, 47, 35, 6, 36], 'out': 59, 'orig_idx': 4},
#   {'input': [35, 6, 47, 17, 28, 26, 36], 'out': 55, 'orig_idx': 0},
#   {'input': [35, 26, 47, 28, 6, 17, 36], 'out': 55, 'orig_idx': 0},
#   {'input': [17, 26, 6, 28, 35, 47, 36], 'out': 59, 'orig_idx': 4},
#   {'input': [47, 17, 26, 35, 6, 28, 36], 'out': 58, 'orig_idx': 3},
#   {'input': [38, 32, 12, 46, 47, 14, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [32, 38, 47, 12, 46, 14, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [32, 47, 14, 38, 12, 46, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [46, 47, 38, 12, 14, 32, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [47, 46, 12, 32, 14, 38, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [38, 14, 32, 47, 12, 46, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [12, 38, 32, 14, 46, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [38, 47, 14, 12, 46, 32, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [47, 14, 12, 38, 32, 46, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [47, 14, 32, 12, 46, 38, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [47, 12, 38, 14, 32, 46, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [47, 32, 46, 12, 14, 38, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [46, 14, 38, 47, 12, 32, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [47, 12, 46, 14, 38, 32, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [47, 12, 14, 46, 38, 32, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [12, 38, 14, 46, 32, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [47, 32, 46, 12, 38, 14, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [12, 46, 14, 32, 47, 38, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [32, 38, 14, 47, 12, 46, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [14, 12, 38, 32, 47, 46, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [47, 33, 14, 29, 46, 38, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [38, 14, 33, 47, 29, 46, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [47, 29, 14, 46, 33, 38, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [29, 47, 14, 33, 38, 46, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [29, 47, 38, 14, 46, 33, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [14, 29, 38, 47, 33, 46, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [46, 47, 33, 29, 14, 38, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [46, 38, 29, 14, 33, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [33, 46, 14, 38, 29, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [29, 38, 47, 46, 33, 14, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [29, 47, 14, 33, 46, 38, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [14, 33, 38, 47, 29, 46, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [46, 14, 38, 29, 33, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [47, 14, 33, 38, 46, 29, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [46, 38, 33, 29, 47, 14, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [38, 14, 46, 29, 47, 33, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [33, 29, 14, 38, 46, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [29, 33, 47, 46, 14, 38, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [33, 38, 47, 14, 29, 46, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [29, 46, 47, 14, 38, 33, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [38, 27, 47, 7, 9, 46, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [27, 38, 9, 47, 7, 46, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [7, 46, 27, 9, 38, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [38, 9, 27, 46, 47, 7, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [7, 27, 47, 38, 9, 46, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [7, 46, 27, 9, 47, 38, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [47, 9, 7, 27, 46, 38, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [7, 38, 9, 46, 27, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [46, 47, 9, 38, 7, 27, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [9, 38, 27, 46, 7, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [46, 47, 9, 27, 7, 38, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [9, 7, 27, 38, 47, 46, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [38, 46, 27, 7, 9, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [27, 7, 47, 46, 38, 9, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [27, 38, 9, 47, 46, 7, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [38, 47, 27, 46, 9, 7, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [7, 47, 9, 27, 38, 46, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [38, 46, 9, 7, 27, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [46, 27, 7, 47, 38, 9, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [9, 47, 27, 7, 46, 38, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [47, 46, 38, 12, 10, 8, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [12, 38, 47, 10, 46, 8, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [12, 46, 38, 8, 47, 10, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [47, 10, 46, 8, 38, 12, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [8, 47, 46, 10, 38, 12, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [10, 12, 8, 47, 38, 46, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [47, 46, 8, 12, 10, 38, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [47, 8, 10, 38, 12, 46, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [8, 12, 47, 10, 46, 38, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [8, 46, 38, 47, 10, 12, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [8, 46, 10, 12, 47, 38, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [8, 38, 46, 10, 47, 12, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [46, 8, 38, 10, 12, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [8, 47, 38, 46, 12, 10, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [12, 8, 38, 47, 46, 10, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [12, 47, 38, 10, 46, 8, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [47, 8, 46, 12, 10, 38, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [38, 8, 12, 10, 46, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [46, 12, 8, 47, 10, 38, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [46, 38, 12, 8, 47, 10, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [46, 18, 7, 38, 22, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [46, 22, 38, 18, 7, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [18, 7, 47, 22, 38, 46, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [18, 47, 7, 46, 22, 38, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [46, 47, 22, 18, 7, 38, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [18, 46, 47, 38, 22, 7, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [18, 46, 47, 22, 38, 7, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [22, 46, 38, 7, 18, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [7, 38, 46, 18, 47, 22, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [47, 18, 38, 22, 7, 46, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [7, 46, 22, 18, 47, 38, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [38, 7, 22, 18, 47, 46, 48], 'out': 59, 'orig_idx': 4},
#   {'input': [47, 38, 18, 46, 22, 7, 48], 'out': 55, 'orig_idx': 0},
#   {'input': [22, 18, 38, 7, 46, 47, 48], 'out': 60, 'orig_idx': 5},
#   {'input': [18, 46, 47, 22, 7, 38, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [7, 46, 47, 38, 18, 22, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [38, 7, 47, 22, 18, 46, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [22, 46, 47, 18, 38, 7, 48], 'out': 57, 'orig_idx': 2},
#   {'input': [22, 7, 18, 47, 46, 38, 48], 'out': 58, 'orig_idx': 3},
#   {'input': [22, 47, 46, 7, 38, 18, 48], 'out': 56, 'orig_idx': 1},
#   {'input': [22, 40, 19, 13, 49, 46, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [40, 13, 22, 46, 49, 19, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [40, 46, 49, 22, 19, 13, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [40, 46, 49, 19, 13, 22, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [49, 13, 46, 22, 40, 19, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [22, 40, 46, 19, 13, 49, 50], 'out': 60, 'orig_idx': 5},
#   {'input': [46, 22, 49, 40, 13, 19, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [49, 13, 19, 22, 40, 46, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [19, 22, 49, 46, 13, 40, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [46, 13, 22, 49, 19, 40, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 22, 49, 19, 46, 40, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [49, 13, 40, 46, 19, 22, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [19, 13, 22, 40, 49, 46, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [46, 22, 49, 13, 19, 40, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [13, 49, 46, 22, 40, 19, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [46, 22, 13, 40, 49, 19, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [13, 22, 46, 49, 40, 19, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [19, 40, 46, 49, 13, 22, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [13, 49, 40, 19, 22, 46, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [49, 19, 13, 22, 40, 46, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [7, 28, 46, 49, 32, 40, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [28, 32, 49, 40, 7, 46, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [28, 46, 40, 49, 7, 32, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [32, 46, 40, 28, 49, 7, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [7, 40, 32, 49, 46, 28, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [49, 32, 46, 28, 7, 40, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [7, 49, 28, 40, 46, 32, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [40, 49, 7, 46, 32, 28, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [7, 49, 46, 28, 40, 32, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [32, 7, 40, 49, 46, 28, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [28, 32, 7, 46, 40, 49, 50], 'out': 60, 'orig_idx': 5},
#   {'input': [32, 7, 28, 49, 46, 40, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [28, 49, 7, 46, 32, 40, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [28, 40, 32, 7, 49, 46, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [7, 32, 28, 46, 49, 40, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [7, 46, 28, 40, 32, 49, 50], 'out': 60, 'orig_idx': 5},
#   {'input': [49, 28, 32, 40, 7, 46, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [28, 7, 32, 40, 46, 49, 50], 'out': 60, 'orig_idx': 5},
#   {'input': [49, 40, 28, 46, 7, 32, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [28, 32, 46, 7, 40, 49, 50], 'out': 60, 'orig_idx': 5},
#   {'input': [46, 49, 23, 40, 29, 9, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [23, 29, 49, 9, 46, 40, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [46, 23, 40, 49, 9, 29, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [23, 9, 40, 29, 49, 46, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [40, 23, 9, 49, 46, 29, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [49, 29, 23, 9, 46, 40, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [40, 23, 46, 9, 49, 29, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [46, 23, 40, 9, 49, 29, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [49, 9, 46, 23, 40, 29, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [49, 9, 46, 29, 23, 40, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [23, 29, 49, 46, 9, 40, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [49, 46, 9, 29, 23, 40, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [46, 40, 23, 9, 49, 29, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [46, 23, 49, 40, 29, 9, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [9, 49, 23, 40, 46, 29, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [49, 23, 9, 29, 46, 40, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [29, 49, 9, 23, 46, 40, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [46, 9, 49, 23, 40, 29, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [23, 40, 46, 9, 49, 29, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [40, 9, 29, 23, 49, 46, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [49, 7, 46, 2, 25, 40, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [40, 2, 25, 46, 49, 7, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [40, 7, 46, 49, 2, 25, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [40, 7, 25, 49, 2, 46, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [46, 49, 25, 7, 40, 2, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [40, 46, 49, 25, 7, 2, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [40, 25, 2, 49, 46, 7, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [7, 40, 49, 25, 2, 46, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [25, 40, 49, 7, 2, 46, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [7, 49, 40, 2, 46, 25, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [2, 40, 49, 25, 46, 7, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [7, 40, 46, 49, 2, 25, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [2, 46, 40, 7, 49, 25, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [25, 40, 2, 49, 46, 7, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [49, 2, 25, 40, 46, 7, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [25, 40, 49, 46, 7, 2, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [7, 2, 49, 46, 25, 40, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [2, 49, 40, 46, 25, 7, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [25, 40, 49, 7, 46, 2, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [46, 7, 25, 49, 40, 2, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [46, 49, 25, 18, 36, 40, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [49, 25, 46, 18, 36, 40, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [40, 36, 25, 18, 46, 49, 50], 'out': 60, 'orig_idx': 5},
#   {'input': [46, 36, 18, 25, 40, 49, 50], 'out': 60, 'orig_idx': 5},
#   {'input': [25, 40, 18, 36, 46, 49, 50], 'out': 60, 'orig_idx': 5},
#   {'input': [46, 18, 25, 36, 40, 49, 50], 'out': 60, 'orig_idx': 5},
#   {'input': [25, 46, 36, 40, 49, 18, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [36, 46, 18, 40, 49, 25, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [49, 18, 40, 36, 46, 25, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [25, 18, 46, 40, 49, 36, 50], 'out': 59, 'orig_idx': 4},
#   {'input': [25, 49, 18, 46, 40, 36, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [49, 25, 18, 46, 40, 36, 50], 'out': 55, 'orig_idx': 0},
#   {'input': [36, 25, 18, 49, 46, 40, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [25, 18, 40, 49, 46, 36, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [36, 40, 25, 46, 18, 49, 50], 'out': 60, 'orig_idx': 5},
#   {'input': [40, 36, 46, 25, 18, 49, 50], 'out': 60, 'orig_idx': 5},
#   {'input': [25, 49, 40, 18, 46, 36, 50], 'out': 56, 'orig_idx': 1},
#   {'input': [40, 36, 49, 18, 25, 46, 50], 'out': 57, 'orig_idx': 2},
#   {'input': [46, 40, 36, 49, 25, 18, 50], 'out': 58, 'orig_idx': 3},
#   {'input': [18, 49, 25, 36, 40, 46, 50], 'out': 56, 'orig_idx': 1},
#   ...]}
